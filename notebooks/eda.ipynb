# %%
from src.utils.data_cleaning import clean_dataset
from datasets import load_dataset


dataset = load_dataset("wmt17", "de-en", split="train[:1000000]")
cleaned_data = clean_dataset(dataset, max_length=64)
# Out:
# filtering out all examples with source or target length less than 5 or more than 64

# %%
cleaned_data[0]
# Out:
# {'de': 'Ich erkläre die am Freitag, dem 17. Dezember unterbrochene Sitzungsperiode des Europäischen Parlaments für wiederaufgenommen, wünsche Ihnen nochmals alles Gute zum Jahreswechsel und hoffe, daß Sie schöne Ferien hatten.',
#  'en': 'I declare resumed the session of the European Parliament adjourned on Friday 17 December 1999, and I would like once again to wish you a happy new year in the hope that you enjoyed a pleasant festive period.',
#  'src': 'ich erkläre die am freitag, dem 17. dezember unterbrochene sitzungsperiode des europäischen parlaments für wiederaufgenommen, wünsche ihnen nochmals alles gute zum jahreswechsel und hoffe, daß sie schöne ferien hatten.',
#  'tgt': 'i declare resumed the session of the european parliament adjourned on friday 17 december 1999, and i would like once again to wish you a happy new year in the hope that you enjoyed a pleasant festive period.'}

# %%
# plot the sentence length distribution
import seaborn as sns

sns.histplot([len(x['src'].split()) for x in cleaned_data])
# Out:
# <Axes: ylabel='Count'>
